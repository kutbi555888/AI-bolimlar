# %%
pip install transformers sentencepiece
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: transformers in C:\Users\xolmu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages (5.16.1)
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 20.9 MB/s  0:00:00
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: C:\Users\xolmu\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-8B")
# Out:
# ...
# config.json:   0%|          | 0.00/728 [00:00<?, ?B/s]
# C:\Users\xolmu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\xolmu\.cache\huggingface\hub\models--Qwen--Qwen3-8B. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
sentence = "Hello, How Are You?"

# %%
tokens = tokenizer.tokenize(sentence)
tokens
# Out:
# ['Hello', ',', 'ĠHow', 'ĠAre', 'ĠYou', '?']

# %%
len(sentence.split())
# Out:
# 4

# %%
len(tokens)
# Out:
# 6

# %%
sentence = "Salom,ishlaringqanday?"

tokenizer.tokenize(sentence)
# Out:
# ['Sal', 'om', ',', 'ish', 'l', 'aring', 'q', 'and', 'ay', '?']

# %%
ids = tokenizer.encode(sentence)

ids
# Out:
# [17245, 316, 11, 812, 75, 3249, 80, 437, 352, 30]

# %%
tokenizer.decode(ids)
# Out:
# 'Salom,ishlaringqanday?'

# %%
examples = [
    "Qween",
    "2026",
    "😊",
    "너 이름 뭐야?",
    "Salom barchaga"
]

for text in examples:
    print("=" * 40)
    print(text)
    print(tokenizer.tokenize(text))
# Out:
# ...
# Qween
# ['Q', 'ween']
# ...
# 2026
# ['2', '0', '2', '6']
# ...
# 😊
# ['ðŁĺĬ']
# ...
# 너 이름 뭐야?
# ['ëĦĪ', 'ĠìĿ´ë¦Ħ', 'Ġë', 'ŃĲ', 'ìķ¼', '?']
# ...
# Salom barchaga
# ['Sal', 'om', 'Ġb', 'arch', 'aga']

# %%
# Qwen/Qwen3-8B modelini hajmini hisoblash

#Parametrs to tokens to size
# Approximation:
# 1 token ≈ 4 bytes (English text)
#paramters=124M (chincella laws)

# 8.2 milliard × 20 = 164 milliard
# Raqam bilan:
# 8,200,000,000 × 20 = 164,000,000,000
tokens = 164_000_000_000   # 164 Billion tokens

bytes_size = tokens * 4
kb = bytes_size / 1024
mb = kb / 1024
gb = mb / 1024

print(f"Training Tokens : {tokens:,}")
print(f"Approx Dataset Size : {gb:.2f} GB")
# Out:
# Training Tokens : 164,000,000,000
# Approx Dataset Size : 610.95 GB

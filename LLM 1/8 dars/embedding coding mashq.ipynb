# %%
from transformers import AutoModel

# %%
model = AutoModel.from_pretrained("convaiinnovations/laya-multilingual")
# model = AutoModel.from_pretrained("DeepSeek-V4-Pro-DSpark ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = AutoModel.from_pretrained("convaiinnovations/laya-multilingual")
#       2 # model = AutoModel.from_pretrained("DeepSeek-V4-Pro-DSpark ")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\auto\auto_factory.py:336, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     333 if kwargs.get("quantization_config") is not None:
#     334     _ = kwargs.pop("quantization_config")
# --> 336 config, kwargs = AutoConfig.from_pretrained(
#     337     pretrained_model_name_or_path,
#     338     return_unused_kwargs=True,
#     339     code_revision=code_revision,
#     340     _commit_hash=commit_hash,
#     341     **hub_kwargs,
#     342     **kwargs,
#     343 )
#     345 # A concrete dtype is absorbed into the config above and then dropped at the composite
#     346 # `get_text_config()` swap, so re-inject the user's value as an explicit kwarg to force the model's
#     347 # `from_pretrained` to honor it over the config's saved dtype (#46459).
#     348 if kwargs_orig.get("torch_dtype", None) is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\auto\configuration_auto.py:433, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     421         raise ValueError(
#     422             f"The checkpoint you are trying to load has model type `{config_dict['model_type']}` "
#     423             "but Transformers does not recognize this architecture. This could be because of an "
#    (...)
#     429             "`pip install git+https://github.com/huggingface/transformers.git`"
#     430         )
#     431     return config_class.from_dict(config_dict, **unused_kwargs)
# --> 433 raise ValueError(
#     434     f"Unrecognized model in {pretrained_model_name_or_path}. "
#     435     f"Should have a `model_type` key in its {CONFIG_NAME}."
#     436 )
#
# ValueError: Unrecognized model in convaiinnovations/laya-multilingual. Should have a `model_type` key in its config.json.

# %%
model = AutoModel.from_pretrained("facebook/opt-125m")
# model = AutoModel.from_pretrained("DeepSeek-V4-Pro-DSpark ")
# Out:
# config.json:   0%|          | 0.00/651 [00:00<?, ?B/s]
# C:\Users\xolmu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\xolmu\.cache\huggingface\hub\models--facebook--opt-125m. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# pytorch_model.bin:   0%|          | 0.00/251M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# [transformers] OPTModel LOAD REPORT from: facebook/opt-125m
# Key            | Status     |  |
# ---------------+------------+--+-
# lm_head.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors:   0%|          | 0.00/251M [00:00<?, ?B/s]

# %%
print(model)
# Out:
# OPTModel(
#   (decoder): OPTDecoder(
#     (embed_tokens): Embedding(50272, 768, padding_idx=1)
#     (embed_positions): OPTLearnedPositionalEmbedding(2050, 768)
#     (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True, bias=True)
#     (layers): ModuleList(
#       (0-11): 12 x OPTDecoderLayer(
#         (self_attn): OPTAttention(
#           (k_proj): Linear(in_features=768, out_features=768, bias=True)
#           (v_proj): Linear(in_features=768, out_features=768, bias=True)
#           (q_proj): Linear(in_features=768, out_features=768, bias=True)
#           (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (activation_fn): ReLU()
#         (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True, bias=True)
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True, bias=True)
#       )
#     )
#   )
# )

# %%
model = AutoModel.from_pretrained("Qwen/Qwen2.5-0.5B")
# Out:
# config.json:   0%|          | 0.00/681 [00:00<?, ?B/s]
# C:\Users\xolmu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\xolmu\.cache\huggingface\hub\models--Qwen--Qwen2.5-0.5B. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]

# %%
print(model)
# Out:
# Qwen2Model(
#   (embed_tokens): Embedding(151936, 896)
#   (layers): ModuleList(
#     (0-23): 24 x Qwen2DecoderLayer(
#       (self_attn): Qwen2Attention(
#         (q_proj): Linear(in_features=896, out_features=896, bias=True)
#         (k_proj): Linear(in_features=896, out_features=128, bias=True)
#         (v_proj): Linear(in_features=896, out_features=128, bias=True)
#         (o_proj): Linear(in_features=896, out_features=896, bias=False)
#       )
#       (mlp): Qwen2MLP(
#         (gate_proj): Linear(in_features=896, out_features=4864, bias=False)
#         (up_proj): Linear(in_features=896, out_features=4864, bias=False)
#         (down_proj): Linear(in_features=4864, out_features=896, bias=False)
#         (act_fn): SiLUActivation()
#       )
#       (input_layernorm): Qwen2RMSNorm((896,), eps=1e-06)
#       (post_attention_layernorm): Qwen2RMSNorm((896,), eps=1e-06)
#     )
#   )
#   (norm): Qwen2RMSNorm((896,), eps=1e-06)
#   (rotary_emb): Qwen2RotaryEmbedding()
# )

# %%
print(model.wte)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 print(model.wte)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1967, in Module.__getattr__(self, name)
#    1965     if name in modules:
#    1966         return modules[name]
# -> 1967 raise AttributeError(
#    1968     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1969 )
#
# AttributeError: 'Qwen2Model' object has no attribute 'wte'

# %%
print(model.wpe)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 print(model.wpe)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1967, in Module.__getattr__(self, name)
#    1965     if name in modules:
#    1966         return modules[name]
# -> 1967 raise AttributeError(
#    1968     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1969 )
#
# AttributeError: 'Qwen2Model' object has no attribute 'wpe'

# %%
print(model.wte.weight.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 print(model.wte.weight.shape)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1967, in Module.__getattr__(self, name)
#    1965     if name in modules:
#    1966         return modules[name]
# -> 1967 raise AttributeError(
#    1968     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1969 )
#
# AttributeError: 'Qwen2Model' object has no attribute 'wte'

# %%
print(model.wte.weight[40])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 print(model.wte.weight[40])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1967, in Module.__getattr__(self, name)
#    1965     if name in modules:
#    1966         return modules[name]
# -> 1967 raise AttributeError(
#    1968     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1969 )
#
# AttributeError: 'Qwen2Model' object has no attribute 'wte'

# %% [markdown]
# # Tokenization -> Embeddings

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-0.5B")

text = "I love AI"

ids = tokenizer.encode(text)

print(ids)
# Out:
# tokenizer_config.json:   0%|          | 0.00/7.23k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# [40, 2948, 15235]

# %%
#Convert to Embeddings
inputs = tokenizer(text, return_tensors="pt")

embeddings = model.wte(inputs["input_ids"])

print(embeddings.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 4
#       1 #Convert to Embeddings
#       2 inputs = tokenizer(text, return_tensors="pt")
# ----> 4 embeddings = model.wte(inputs["input_ids"])
#       6 print(embeddings.shape)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1967, in Module.__getattr__(self, name)
#    1965     if name in modules:
#    1966         return modules[name]
# -> 1967 raise AttributeError(
#    1968     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1969 )
#
# AttributeError: 'Qwen2Model' object has no attribute 'wte'

# %%
print(embeddings[0][0][:10])

# But again.[0]-- batch raqami
# [0]- tokenizer position(I love AI)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 print(embeddings[0][0][:10])
#       3 # But again.[0]-- batch raqami
#       4 # [0]- tokenizer position(I love AI)
#
# NameError: name 'embeddings' is not defined

# %%
words = ["cat", "dog", "car"]

for word in words:
    ids = tokenizer(word, return_tensors="pt")["input_ids"]
    emb = model.wte(ids)
    print(word, emb.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 5
#       3 for word in words:
#       4     ids = tokenizer(word, return_tensors="pt")["input_ids"]
# ----> 5     emb = model.wte(ids)
#       6     print(word, emb.shape)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1967, in Module.__getattr__(self, name)
#    1965     if name in modules:
#    1966         return modules[name]
# -> 1967 raise AttributeError(
#    1968     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1969 )
#
# AttributeError: 'Qwen2Model' object has no attribute 'wte'
